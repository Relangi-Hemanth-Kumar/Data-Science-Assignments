# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d416c0eb-bddf-4cd8-bad9-08c6dc85fdae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d416c0eb-bddf-4cd8-bad9-08c6dc85fdae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("glass.csv")
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(df.describe())
# Out:
# <Axes: >

# %%
df.plot(kind='density', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %%
df.plot(kind='box', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %% [markdown]
# Correlation Between Variables

# %%
cor = df.corr(method='pearson')

# %%
cor.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_3989f_row0_col0, #T_3989f_row1_col1, #T_3989f_row2_col2, #T_3989f_row3_col3, #T_3989f_row4_col4, #T_3989f_row5_col5, #T_3989f_row6_col6, #T_3989f_row7_col7, #T_3989f_row8_col8, #T_3989f_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3989f_row0_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_3989f_row0_col2 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_3989f_row0_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_3989f_row0_col4, #T_3989f_row1_col8, #T_3989f_row2_col1, #T_3989f_row2_col3, #T_3989f_row2_col6, #T_3989f_row2_col7, #T_3989f_row2_col9, #T_3989f_row4_col0, #T_3989f_row6_col1, #T_3989f_row6_col5, #T_3989f_row9_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_3989f_row0_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_3989f_row0_col6 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_3989f_row0_col7, #T_3989f_row4_col2 {
# ...

# %% [markdown]
# As seen in the above graph, there is high correlation exists between some of the variables. We can use PCA to reduce the highly correlated variables

# %% [markdown]
# KNN

# %%
import numpy as np
X = np.array(df.iloc[:,3:5])
y = np.array(df['Type'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)

# %%
k_values = np.arange(1,25)
train_accuracy = []
test_accuracy = []
from sklearn.neighbors import KNeighborsClassifier

# %%
for i, k in enumerate(k_values):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train,y_train)
    train_accuracy.append(knn.score(X_train, y_train))
    test_accuracy.append(knn.score(X_test, y_test))

# %%
plt.figure(figsize=[13,8])
plt.plot(k_values, test_accuracy, label = 'Testing Accuracy')
plt.plot(k_values, train_accuracy, label = 'Training Accuracy')
plt.legend()
plt.title('Value VS Accuracy')
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.xticks(k_values)
plt.show()

# %% [markdown]
# k=4 produces the most accurate results

# %%
knn = KNeighborsClassifier(n_neighbors=4)
knn.fit(X_train, y_train)
y_pred_KNeighborsClassifier = knn.predict(X_test)
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

# %%
scores = []
cv_scores = []
score = accuracy_score(y_pred_KNeighborsClassifier,y_test)
scores.append(score)

# %%
score_knn=cross_val_score(knn, X,y, cv=10)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 9 members, which is less than n_splits=10.
#   warnings.warn(

# %%
score_knn.mean()
# Out:
# 0.6127705627705629

# %%
score_knn.std()*2
# Out:
# 0.23547117559816877

# %%
cv_score = score_knn.mean()

# %%
cv_scores.append(cv_score)
cv_scores
# Out:
# [0.6127705627705629]

# %% [markdown]
# Support Vector Machine Accuracy: nearly 60% (61.2%)
